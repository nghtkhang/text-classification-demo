# %%
import torch

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: GeForce RTX 2080 Ti

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (2.2.2)
# Requirement already satisfied: regex in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (2019.12.19)
# Requirement already satisfied: requests in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (2.22.0)
# Requirement already satisfied: sacremoses in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (0.0.35)
# Requirement already satisfied: numpy in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (1.17.3)
# Requirement already satisfied: sentencepiece in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (0.1.85)
# Requirement already satisfied: boto3 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (1.10.42)
# Requirement already satisfied: tqdm in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from transformers) (4.40.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from requests->transformers) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from requests->transformers) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from requests->transformers) (2.8)
# Requirement already satisfied: six in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from sacremoses->transformers) (1.13.0)
# Requirement already satisfied: click in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from sacremoses->transformers) (7.0)
# Requirement already satisfied: joblib in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from sacremoses->transformers) (0.14.0)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from boto3->transformers) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from boto3->transformers) (0.9.4)
# Requirement already satisfied: botocore<1.14.0,>=1.13.42 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from boto3->transformers) (1.13.42)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from botocore<1.14.0,>=1.13.42->boto3->transformers) (0.15.2)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages (from botocore<1.14.0,>=1.13.42->boto3->transformers) (2.8.0)

# %%
from transformers import BertTokenizer
from transformers import BertModel

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')
# Out:
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
model.cuda()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
input_ids = torch.tensor(tokenizer.encode("Hello, my cat is cute", add_special_tokens=True)).unsqueeze(0)  # Batch size 1
outputs = model(input_ids.to(device))

# %%
outputs[0].detach().cpu().numpy().shape
# Out:
# (1, 8, 768)

# %%
import pandas as pd
data_pd = pd.read_csv("IMDB Dataset.csv")

data_pd["label"] = data_pd["sentiment"].map({'positive': 1, 'negative': 0})
data_pd.head()
# Out:
#                                               review sentiment  label
# 0  One of the other reviewers has mentioned that ...  positive      1
# 1  A wonderful little production. <br /><br />The...  positive      1
# 2  I thought this was a wonderful way to spend ti...  positive      1
# 3  Basically there's a family where a little boy ...  negative      0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive      1

# %%
from tqdm import tqdm, tqdm_notebook

# instantiate
tqdm.pandas(tqdm_notebook)

MAX_LEN = 300
#tokenize
input_ids = []
for sentence in tqdm(data_pd["review"]):
  ids = tokenizer.encode(sentence, add_special_tokens=True,max_length = MAX_LEN  )
  input_ids.append(ids)

from keras.preprocessing.sequence import pad_sequences


# Pad our input tokens with value 0.
input_ids = pad_sequences(input_ids, maxlen=MAX_LEN, dtype="long", 
                          value=0, truncating="post", padding="post")
# Out:
# /home/huy/miniconda3/envs/huynt_gpu/lib/python3.7/site-packages/tqdm/std.py:654: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 50000/50000 [02:20<00:00, 354.80it/s]
# Using TensorFlow backend.

# %%
# Create attention masks
attention_masks = []

# For each sentence...
for sent in input_ids:
    
    # Create the attention mask.
    #   - If a token ID is 0, then it's padding, set the mask to 0.
    #   - If a token ID is > 0, then it's a real token, set the mask to 1.
    att_mask = [int(token_id > 0) for token_id in sent]
    
    # Store the attention mask for this sentence.
    attention_masks.append(att_mask)

# %%
# Convert all inputs and labels into torch tensors, the required datatype 
# for our model.
data_inputs = torch.tensor(input_ids[:10000])

data_masks = torch.tensor(attention_masks[:10000])

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

# The DataLoader needs to know our batch size for training, so we specify it 
# here.
# For fine-tuning BERT on a specific task, the authors recommend a batch size of
# 16 or 32.

batch_size = 16



# Create the DataLoader for our data
predict_data = TensorDataset(data_inputs, data_masks)
predict_sampler = SequentialSampler(predict_data)
predict_dataloader = DataLoader(predict_data, sampler=predict_sampler, batch_size=batch_size)

# %%
import numpy as np
model.eval()
bert_output = []

for batch in tqdm(predict_dataloader):
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    b_input_ids, b_input_mask = batch
    with torch.no_grad():
        # Forward pass, calculate logit predictions
        outputs = model(b_input_ids, token_type_ids=None, 
                      attention_mask=b_input_mask)
    logits = outputs[0]
    logits = logits.detach().cpu().numpy()

    first_hidden_state = logits[:,0,:]
    bert_output.append(first_hidden_state)
# Out:
#   0%|          | 0/625 [00:00<?, ?it/s]
#
#
#
#   0%|          | 1/625 [00:00<01:24,  7.40it/s]
#
#
#
#   0%|          | 2/625 [00:00<01:21,  7.61it/s]
#
#
#
#   0%|          | 3/625 [00:00<01:19,  7.82it/s]
#
#
#
#   1%|          | 4/625 [00:00<01:18,  7.93it/s]
#
#
#
#   1%|          | 5/625 [00:00<01:17,  8.00it/s]
#
#
#
#   1%|          | 6/625 [00:00<01:16,  8.06it/s]
#
#
#
#   1%|          | 7/625 [00:00<01:16,  8.10it/s]
#
#
#
#   1%|▏         | 8/625 [00:00<01:15,  8.13it/s]
#
#
#
#   1%|▏         | 9/625 [00:01<01:15,  8.15it/s]
#
#
#
#   2%|▏         | 10/625 [00:01<01:15,  8.16it/s]
#
#
#
#   2%|▏         | 11/625 [00:01<01:15,  8.17it/s]
#
#
#
#   2%|▏         | 12/625 [00:01<01:15,  8.17it/s]
#
#
#
#   2%|▏         | 13/625 [00:01<01:14,  8.18it/s]
#
#
#
#   2%|▏         | 14/625 [00:01<01:14,  8.17it/s]
#
#
#
#   2%|▏         | 15/625 [00:01<01:14,  8.18it/s]
#
#
#
#   3%|▎         | 16/625 [00:01<01:14,  8.18it/s]
#
#
#
#   3%|▎         | 17/625 [00:02<01:14,  8.18it/s]
#
#
#
#   3%|▎         | 18/625 [00:02<01:14,  8.19it/s]
#
#
#
#   3%|▎         | 19/625 [00:02<01:14,  8.17it/s]
#
#
#
#   3%|▎         | 20/625 [00:02<01:13,  8.18it/s]
#
#
#
#   3%|▎         | 21/625 [00:02<01:13,  8.19it/s]
#
#
#
#   4%|▎         | 22/625 [00:02<01:13,  8.18it/s]
#
#
#
#   4%|▎         | 23/625 [00:02<01:13,  8.18it/s]
#
#
#
#   4%|▍         | 24/625 [00:02<01:13,  8.18it/s]
#
#
#
#   4%|▍         | 25/625 [00:03<01:13,  8.18it/s]
#
#
#
#   4%|▍         | 26/625 [00:03<01:13,  8.19it/s]
#
#
#
#   4%|▍         | 27/625 [00:03<01:13,  8.19it/s]
#
#
#
#   4%|▍         | 28/625 [00:03<01:12,  8.19it/s]
#
#
#
#   5%|▍         | 29/625 [00:03<01:12,  8.19it/s]
#
#
#
#   5%|▍         | 30/625 [00:03<01:12,  8.18it/s]
#
#
#
#   5%|▍         | 31/625 [00:03<01:12,  8.18it/s]
#
#
#
#   5%|▌         | 32/625 [00:03<01:12,  8.19it/s]
#
#
#
#   5%|▌         | 33/625 [00:04<01:12,  8.18it/s]
#
#
#
#   5%|▌         | 34/625 [00:04<01:12,  8.18it/s]
#
#
#
#   6%|▌         | 35/625 [00:04<01:12,  8.18it/s]
#
#
#
#   6%|▌         | 36/625 [00:04<01:12,  8.17it/s]
#
#
#
#   6%|▌         | 37/625 [00:04<01:11,  8.17it/s]
#
#
#
#   6%|▌         | 38/625 [00:04<01:11,  8.16it/s]
#
#
#
#   6%|▌         | 39/625 [00:04<01:11,  8.16it/s]
#
#
#
#   6%|▋         | 40/625 [00:04<01:11,  8.17it/s]
#
#
#
#   7%|▋         | 41/625 [00:05<01:11,  8.17it/s]
#
#
#
#   7%|▋         | 42/625 [00:05<01:11,  8.16it/s]
#
#
#
#   7%|▋         | 43/625 [00:05<01:11,  8.16it/s]
#
#
#
#   7%|▋         | 44/625 [00:05<01:11,  8.15it/s]
#
#
#
#   7%|▋         | 45/625 [00:05<01:11,  8.16it/s]
#
#
#
#   7%|▋         | 46/625 [00:05<01:10,  8.16it/s]
#
#
#
#   8%|▊         | 47/625 [00:05<01:10,  8.16it/s]
#
#
#
#   8%|▊         | 48/625 [00:05<01:10,  8.17it/s]
#
#
#
#   8%|▊         | 49/625 [00:06<01:10,  8.18it/s]
#
#
#
#   8%|▊         | 50/625 [00:06<01:10,  8.18it/s]
#
#
#
#   8%|▊         | 51/625 [00:06<01:10,  8.18it/s]
#
#
#
#   8%|▊         | 52/625 [00:06<01:10,  8.18it/s]
#
#
#
#   8%|▊         | 53/625 [00:06<01:09,  8.18it/s]
#
#
#
#   9%|▊         | 54/625 [00:06<01:09,  8.18it/s]
#
#
#
#   9%|▉         | 55/625 [00:06<01:09,  8.17it/s]
#
#
#
#   9%|▉         | 56/625 [00:06<01:09,  8.17it/s]
#
#
#
#   9%|▉         | 57/625 [00:06<01:09,  8.17it/s]
#
#
#
#   9%|▉         | 58/625 [00:07<01:09,  8.17it/s]
#
#
#
#   9%|▉         | 59/625 [00:07<01:09,  8.18it/s]
#
#
#
#  10%|▉         | 60/625 [00:07<01:09,  8.18it/s]
#
#
#
#  10%|▉         | 61/625 [00:07<01:08,  8.18it/s]
#
#
#
#  10%|▉         | 62/625 [00:07<01:08,  8.17it/s]
#
#
#
#  10%|█         | 63/625 [00:07<01:08,  8.17it/s]
#
#
#
#  10%|█         | 64/625 [00:07<01:08,  8.16it/s]
#
#
#
#  10%|█         | 65/625 [00:07<01:08,  8.16it/s]
#
#
#
#  11%|█         | 66/625 [00:08<01:08,  8.16it/s]
#
#
#
#  11%|█         | 67/625 [00:08<01:08,  8.16it/s]
#
#
#
#  11%|█         | 68/625 [00:08<01:08,  8.16it/s]
#
#
#
#  11%|█         | 69/625 [00:08<01:08,  8.17it/s]
#
#
#
#  11%|█         | 70/625 [00:08<01:07,  8.17it/s]
#
#
#
#  11%|█▏        | 71/625 [00:08<01:07,  8.17it/s]
#
#
#
#  12%|█▏        | 72/625 [00:08<01:07,  8.16it/s]
#
#
#
#  12%|█▏        | 73/625 [00:08<01:07,  8.16it/s]
#
#
#
#  12%|█▏        | 74/625 [00:09<01:07,  8.16it/s]
#
#
#
#  12%|█▏        | 75/625 [00:09<01:07,  8.16it/s]
#
#
#
#  12%|█▏        | 76/625 [00:09<01:07,  8.16it/s]
#
#
#
#  12%|█▏        | 77/625 [00:09<01:07,  8.16it/s]
#
#
#
#  12%|█▏        | 78/625 [00:09<01:06,  8.17it/s]
#
#
#
#  13%|█▎        | 79/625 [00:09<01:06,  8.15it/s]
#
#
#
#  13%|█▎        | 80/625 [00:09<01:06,  8.16it/s]
#
#
#
#  13%|█▎        | 81/625 [00:09<01:06,  8.16it/s]
#
#
#
#  13%|█▎        | 82/625 [00:10<01:06,  8.16it/s]
#
#
#
#  13%|█▎        | 83/625 [00:10<01:06,  8.17it/s]
#
#
#
#  13%|█▎        | 84/625 [00:10<01:06,  8.17it/s]
#
#
#
#  14%|█▎        | 85/625 [00:10<01:06,  8.17it/s]
#
#
#
#  14%|█▍        | 86/625 [00:10<01:05,  8.17it/s]
#
#
#
#  14%|█▍        | 87/625 [00:10<01:05,  8.16it/s]
#
#
#
#  14%|█▍        | 88/625 [00:10<01:05,  8.16it/s]
#
#
#
#  14%|█▍        | 89/625 [00:10<01:05,  8.16it/s]
#
#
#
#  14%|█▍        | 90/625 [00:11<01:05,  8.16it/s]
#
#
#
#  15%|█▍        | 91/625 [00:11<01:05,  8.16it/s]
#
#
#
#  15%|█▍        | 92/625 [00:11<01:05,  8.16it/s]
#
#
#
#  15%|█▍        | 93/625 [00:11<01:05,  8.16it/s]
#
#
#
#  15%|█▌        | 94/625 [00:11<01:05,  8.16it/s]
#
#
#
#  15%|█▌        | 95/625 [00:11<01:04,  8.15it/s]
#
#
#
#  15%|█▌        | 96/625 [00:11<01:04,  8.15it/s]
#
#
#
#  16%|█▌        | 97/625 [00:11<01:04,  8.16it/s]
#
#
#
#  16%|█▌        | 98/625 [00:12<01:04,  8.16it/s]
#
#
#
#  16%|█▌        | 99/625 [00:12<01:04,  8.16it/s]
#
#
#
#  16%|█▌        | 100/625 [00:12<01:04,  8.16it/s]
#
#
#
#  16%|█▌        | 101/625 [00:12<01:04,  8.16it/s]
#
#
#
#  16%|█▋        | 102/625 [00:12<01:04,  8.17it/s]
#
#
#
#  16%|█▋        | 103/625 [00:12<01:03,  8.17it/s]
#
#
#
#  17%|█▋        | 104/625 [00:12<01:03,  8.16it/s]
#
#
#
#  17%|█▋        | 105/625 [00:12<01:03,  8.16it/s]
#
#
#
#  17%|█▋        | 106/625 [00:12<01:03,  8.16it/s]
#
#
#
#  17%|█▋        | 107/625 [00:13<01:03,  8.16it/s]
#
#
#
#  17%|█▋        | 108/625 [00:13<01:03,  8.15it/s]
#
#
#
#  17%|█▋        | 109/625 [00:13<01:03,  8.16it/s]
#
#
#
#  18%|█▊        | 110/625 [00:13<01:03,  8.16it/s]
#
#
#
#  18%|█▊        | 111/625 [00:13<01:02,  8.16it/s]
#
#
#
#  18%|█▊        | 112/625 [00:13<01:02,  8.15it/s]
#
#
#
#  18%|█▊        | 113/625 [00:13<01:02,  8.16it/s]
#
#
#
#  18%|█▊        | 114/625 [00:13<01:02,  8.16it/s]
#
#
#
#  18%|█▊        | 115/625 [00:14<01:02,  8.16it/s]
#
#
#
#  19%|█▊        | 116/625 [00:14<01:02,  8.16it/s]
#
#
#
#  19%|█▊        | 117/625 [00:14<01:02,  8.16it/s]
#
#
#
#  19%|█▉        | 118/625 [00:14<01:02,  8.16it/s]
#
#
#
#  19%|█▉        | 119/625 [00:14<01:02,  8.16it/s]
#
#
#
#  19%|█▉        | 120/625 [00:14<01:01,  8.16it/s]
#
#
#
#  19%|█▉        | 121/625 [00:14<01:01,  8.16it/s]
#
#
#
#  20%|█▉        | 122/625 [00:14<01:01,  8.16it/s]
#
#
#
#  20%|█▉        | 123/625 [00:15<01:01,  8.16it/s]
#
#
#
#  20%|█▉        | 124/625 [00:15<01:01,  8.16it/s]
#
#
#
#  20%|██        | 125/625 [00:15<01:01,  8.16it/s]
#
#
#
#  20%|██        | 126/625 [00:15<01:01,  8.15it/s]
#  20%|██        | 127/625 [00:15<01:01,  8.15it/s]
#
#
#
#  20%|██        | 128/625 [00:15<01:00,  8.15it/s]
#
#
#
#  21%|██        | 129/625 [00:15<01:00,  8.15it/s]
#
#
#
#  21%|██        | 130/625 [00:15<01:00,  8.15it/s]
#
#
#
#  21%|██        | 131/625 [00:16<01:00,  8.15it/s]
#
#
#
#  21%|██        | 132/625 [00:16<01:00,  8.15it/s]
#
#
#
#  21%|██▏       | 133/625 [00:16<01:00,  8.15it/s]
#
#
#
#  21%|██▏       | 134/625 [00:16<01:00,  8.18it/s]
#
#
#
#  22%|██▏       | 135/625 [00:16<00:59,  8.17it/s]
#
#
#
#  22%|██▏       | 136/625 [00:16<00:59,  8.15it/s]
#
#
#
#  22%|██▏       | 137/625 [00:16<00:59,  8.15it/s]
#
#
#
#  22%|██▏       | 138/625 [00:16<00:59,  8.14it/s]
#
#
#
#  22%|██▏       | 139/625 [00:17<00:59,  8.14it/s]
#
#
#
#  22%|██▏       | 140/625 [00:17<00:59,  8.13it/s]
#
#
#
#  23%|██▎       | 141/625 [00:17<00:59,  8.13it/s]
#
#
#
#  23%|██▎       | 142/625 [00:17<00:59,  8.14it/s]
#
#
#
#  23%|██▎       | 143/625 [00:17<00:59,  8.14it/s]
#
#
#
#  23%|██▎       | 144/625 [00:17<00:59,  8.13it/s]
#
#
#
#  23%|██▎       | 145/625 [00:17<00:59,  8.13it/s]
#
#
#
#  23%|██▎       | 146/625 [00:17<00:58,  8.13it/s]
#
#
#
#  24%|██▎       | 147/625 [00:18<00:58,  8.13it/s]
#
#
#
#  24%|██▎       | 148/625 [00:18<00:58,  8.14it/s]
#
#
#
#  24%|██▍       | 149/625 [00:18<00:58,  8.14it/s]
#
#
#
#  24%|██▍       | 150/625 [00:18<00:58,  8.14it/s]
#
#
#
#  24%|██▍       | 151/625 [00:18<00:58,  8.14it/s]
#
#
#
#  24%|██▍       | 152/625 [00:18<00:58,  8.13it/s]
#
#
#
#  24%|██▍       | 153/625 [00:18<00:58,  8.13it/s]
#
#
#
#  25%|██▍       | 154/625 [00:18<00:57,  8.13it/s]
#
#
#
#  25%|██▍       | 155/625 [00:18<00:57,  8.14it/s]
#
#
#
#  25%|██▍       | 156/625 [00:19<00:57,  8.13it/s]
#
#
#
#  25%|██▌       | 157/625 [00:19<00:57,  8.13it/s]
#
#
#
#  25%|██▌       | 158/625 [00:19<00:57,  8.13it/s]
#
#
#
#  25%|██▌       | 159/625 [00:19<00:57,  8.13it/s]
#
#
#
#  26%|██▌       | 160/625 [00:19<00:57,  8.13it/s]
#
#
#
#  26%|██▌       | 161/625 [00:19<00:57,  8.14it/s]
#
#
#
#  26%|██▌       | 162/625 [00:19<00:56,  8.13it/s]
#
#
#
#  26%|██▌       | 163/625 [00:19<00:56,  8.14it/s]
#
#
#
#  26%|██▌       | 164/625 [00:20<00:56,  8.14it/s]
#
#
#
#  26%|██▋       | 165/625 [00:20<00:56,  8.13it/s]
#
#
#
#  27%|██▋       | 166/625 [00:20<00:56,  8.14it/s]
#
#
#
#  27%|██▋       | 167/625 [00:20<00:56,  8.14it/s]
#
#
#
#  27%|██▋       | 168/625 [00:20<00:56,  8.14it/s]
#
#
#
#  27%|██▋       | 169/625 [00:20<00:56,  8.13it/s]
#
#
#
#  27%|██▋       | 170/625 [00:20<00:55,  8.13it/s]
#
#
#
#  27%|██▋       | 171/625 [00:20<00:55,  8.13it/s]
#
#
#
#  28%|██▊       | 172/625 [00:21<00:55,  8.14it/s]
#
#
#
#  28%|██▊       | 173/625 [00:21<00:55,  8.14it/s]
#
#
#
#  28%|██▊       | 174/625 [00:21<00:55,  8.14it/s]
#
#
#
#  28%|██▊       | 175/625 [00:21<00:55,  8.14it/s]
#
#
#
#  28%|██▊       | 176/625 [00:21<00:55,  8.14it/s]
#
#
#
#  28%|██▊       | 177/625 [00:21<00:55,  8.14it/s]
#
#
#
#  28%|██▊       | 178/625 [00:21<00:54,  8.13it/s]
#
#
#
#  29%|██▊       | 179/625 [00:21<00:54,  8.13it/s]
#
#
#
#  29%|██▉       | 180/625 [00:22<00:54,  8.13it/s]
#
#
#
#  29%|██▉       | 181/625 [00:22<00:54,  8.13it/s]
#
#
#
#  29%|██▉       | 182/625 [00:22<00:54,  8.13it/s]
#
#
#
#  29%|██▉       | 183/625 [00:22<00:54,  8.13it/s]
#
#
#
#  29%|██▉       | 184/625 [00:22<00:54,  8.13it/s]
#
#
#
#  30%|██▉       | 185/625 [00:22<00:54,  8.13it/s]
#
#
#
#  30%|██▉       | 186/625 [00:22<00:54,  8.13it/s]
#
#
#
#  30%|██▉       | 187/625 [00:22<00:53,  8.14it/s]
#
#
#
#  30%|███       | 188/625 [00:23<00:53,  8.13it/s]
#
#
#
#  30%|███       | 189/625 [00:23<00:53,  8.13it/s]
#
#
#
#  30%|███       | 190/625 [00:23<00:53,  8.13it/s]
#
#
#
#  31%|███       | 191/625 [00:23<00:53,  8.12it/s]
#
#
#
#  31%|███       | 192/625 [00:23<00:53,  8.12it/s]
#
#
#
#  31%|███       | 193/625 [00:23<00:53,  8.12it/s]
#
#
#
#  31%|███       | 194/625 [00:23<00:53,  8.11it/s]
#
#
#
#  31%|███       | 195/625 [00:23<00:52,  8.12it/s]
#
#
#
#  31%|███▏      | 196/625 [00:24<00:52,  8.13it/s]
#
#
#
#  32%|███▏      | 197/625 [00:24<00:52,  8.13it/s]
#
#
#
#  32%|███▏      | 198/625 [00:24<00:52,  8.13it/s]
#
#
#
#  32%|███▏      | 199/625 [00:24<00:52,  8.13it/s]
#
#
#
#  32%|███▏      | 200/625 [00:24<00:52,  8.13it/s]
#
#
#
#  32%|███▏      | 201/625 [00:24<00:52,  8.12it/s]
#
#
#
#  32%|███▏      | 202/625 [00:24<00:52,  8.12it/s]
#
#
#
#  32%|███▏      | 203/625 [00:24<00:51,  8.12it/s]
#
#
#
#  33%|███▎      | 204/625 [00:25<00:51,  8.12it/s]
#
#
#
#  33%|███▎      | 205/625 [00:25<00:51,  8.12it/s]
#
#
#
#  33%|███▎      | 206/625 [00:25<00:51,  8.12it/s]
#
#
#
#  33%|███▎      | 207/625 [00:25<00:51,  8.12it/s]
#
#
#
#  33%|███▎      | 208/625 [00:25<00:51,  8.13it/s]
#
#
#
#  33%|███▎      | 209/625 [00:25<00:51,  8.12it/s]
#
#
#
#  34%|███▎      | 210/625 [00:25<00:51,  8.12it/s]
#
#
#
#  34%|███▍      | 211/625 [00:25<00:50,  8.12it/s]
#
#
#
#  34%|███▍      | 212/625 [00:26<00:50,  8.12it/s]
#
#
#
#  34%|███▍      | 213/625 [00:26<00:50,  8.12it/s]
#
#
#
#  34%|███▍      | 214/625 [00:26<00:50,  8.12it/s]
#
#
#
#  34%|███▍      | 215/625 [00:26<00:50,  8.11it/s]
#
#
#
#  35%|███▍      | 216/625 [00:26<00:50,  8.11it/s]
#
#
#
#  35%|███▍      | 217/625 [00:26<00:50,  8.11it/s]
#
#
#
#  35%|███▍      | 218/625 [00:26<00:50,  8.11it/s]
#
#
#
#  35%|███▌      | 219/625 [00:26<00:50,  8.12it/s]
#
#
#
#  35%|███▌      | 220/625 [00:26<00:49,  8.12it/s]
#
#
#
#  35%|███▌      | 221/625 [00:27<00:49,  8.12it/s]
#
#
#
#  36%|███▌      | 222/625 [00:27<00:49,  8.12it/s]
#
#
#
#  36%|███▌      | 223/625 [00:27<00:49,  8.12it/s]
#
#
#
#  36%|███▌      | 224/625 [00:27<00:49,  8.12it/s]
#
#
#
#  36%|███▌      | 225/625 [00:27<00:49,  8.12it/s]
#
#
#
#  36%|███▌      | 226/625 [00:27<00:49,  8.11it/s]
#
#
#
#  36%|███▋      | 227/625 [00:27<00:49,  8.12it/s]
#
#
#
#  36%|███▋      | 228/625 [00:27<00:48,  8.12it/s]
#
#
#
#  37%|███▋      | 229/625 [00:28<00:48,  8.12it/s]
#
#
#
#  37%|███▋      | 230/625 [00:28<00:48,  8.12it/s]
#
#
#
#  37%|███▋      | 231/625 [00:28<00:48,  8.12it/s]
#
#
#
#  37%|███▋      | 232/625 [00:28<00:48,  8.12it/s]
#
#
#
#  37%|███▋      | 233/625 [00:28<00:48,  8.12it/s]
#
#
#
#  37%|███▋      | 234/625 [00:28<00:48,  8.12it/s]
#
#
#
#  38%|███▊      | 235/625 [00:28<00:48,  8.12it/s]
#
#
#
#  38%|███▊      | 236/625 [00:28<00:47,  8.12it/s]
#
#
#
#  38%|███▊      | 237/625 [00:29<00:47,  8.12it/s]
#
#
#
#  38%|███▊      | 238/625 [00:29<00:47,  8.12it/s]
#
#
#
#  38%|███▊      | 239/625 [00:29<00:47,  8.12it/s]
#
#
#
#  38%|███▊      | 240/625 [00:29<00:47,  8.12it/s]
#
#
#
#  39%|███▊      | 241/625 [00:29<00:47,  8.12it/s]
#
#
#
#  39%|███▊      | 242/625 [00:29<00:47,  8.11it/s]
#
#
#
#  39%|███▉      | 243/625 [00:29<00:47,  8.11it/s]
#
#
#
#  39%|███▉      | 244/625 [00:29<00:46,  8.11it/s]
#
#
#
#  39%|███▉      | 245/625 [00:30<00:46,  8.12it/s]
#
#
#
#  39%|███▉      | 246/625 [00:30<00:46,  8.12it/s]
#
#
#
#  40%|███▉      | 247/625 [00:30<00:46,  8.12it/s]
#
#
#
#  40%|███▉      | 248/625 [00:30<00:46,  8.12it/s]
#
#
#
#  40%|███▉      | 249/625 [00:30<00:46,  8.12it/s]
#
#
#
#  40%|████      | 250/625 [00:30<00:46,  8.12it/s]
#
#
#
#  40%|████      | 251/625 [00:30<00:46,  8.12it/s]
#
#
#
#  40%|████      | 252/625 [00:30<00:45,  8.12it/s]
#  40%|████      | 253/625 [00:31<00:45,  8.12it/s]
#
#
#
#  41%|████      | 254/625 [00:31<00:45,  8.12it/s]
#
#
#
#  41%|████      | 255/625 [00:31<00:45,  8.12it/s]
#
#
#
#  41%|████      | 256/625 [00:31<00:45,  8.12it/s]
#
#
#
#  41%|████      | 257/625 [00:31<00:45,  8.11it/s]
#
#
#
#  41%|████▏     | 258/625 [00:31<00:45,  8.11it/s]
#
#
#
#  41%|████▏     | 259/625 [00:31<00:45,  8.10it/s]
#
#
#
#  42%|████▏     | 260/625 [00:31<00:44,  8.11it/s]
#
#
#
#  42%|████▏     | 261/625 [00:32<00:44,  8.11it/s]
#
#
#
#  42%|████▏     | 262/625 [00:32<00:44,  8.12it/s]
#
#
#
#  42%|████▏     | 263/625 [00:32<00:44,  8.11it/s]
#
#
#
#  42%|████▏     | 264/625 [00:32<00:44,  8.11it/s]
#
#
#
#  42%|████▏     | 265/625 [00:32<00:44,  8.11it/s]
#
#
#
#  43%|████▎     | 266/625 [00:32<00:44,  8.11it/s]
#
#
#
#  43%|████▎     | 267/625 [00:32<00:44,  8.11it/s]
#
#
#
#  43%|████▎     | 268/625 [00:32<00:44,  8.11it/s]
#
#
#
#  43%|████▎     | 269/625 [00:33<00:43,  8.11it/s]
#
#
#
#  43%|████▎     | 270/625 [00:33<00:43,  8.11it/s]
#
#
#
#  43%|████▎     | 271/625 [00:33<00:43,  8.11it/s]
#
#
#
#  44%|████▎     | 272/625 [00:33<00:43,  8.12it/s]
#
#
#
#  44%|████▎     | 273/625 [00:33<00:43,  8.12it/s]
#
#
#
#  44%|████▍     | 274/625 [00:33<00:43,  8.11it/s]
#
#
#
#  44%|████▍     | 275/625 [00:33<00:43,  8.11it/s]
#
#
#
#  44%|████▍     | 276/625 [00:33<00:43,  8.10it/s]
#
#
#
#  44%|████▍     | 277/625 [00:34<00:42,  8.10it/s]
#
#
#
#  44%|████▍     | 278/625 [00:34<00:42,  8.10it/s]
#
#
#
#  45%|████▍     | 279/625 [00:34<00:42,  8.11it/s]
#
#
#
#  45%|████▍     | 280/625 [00:34<00:42,  8.11it/s]
#
#
#
#  45%|████▍     | 281/625 [00:34<00:42,  8.11it/s]
#
#
#
#  45%|████▌     | 282/625 [00:34<00:42,  8.10it/s]
#
#
#
#  45%|████▌     | 283/625 [00:34<00:42,  8.11it/s]
#
#
#
#  45%|████▌     | 284/625 [00:34<00:42,  8.10it/s]
#
#
#
#  46%|████▌     | 285/625 [00:35<00:41,  8.10it/s]
#
#
#
#  46%|████▌     | 286/625 [00:35<00:41,  8.10it/s]
#
#
#
#  46%|████▌     | 287/625 [00:35<00:41,  8.11it/s]
#
#
#
#  46%|████▌     | 288/625 [00:35<00:41,  8.11it/s]
#
#
#
#  46%|████▌     | 289/625 [00:35<00:41,  8.11it/s]
#
#
#
#  46%|████▋     | 290/625 [00:35<00:41,  8.10it/s]
#
#
#
#  47%|████▋     | 291/625 [00:35<00:41,  8.10it/s]
#
#
#
#  47%|████▋     | 292/625 [00:35<00:41,  8.10it/s]
#
#
#
#  47%|████▋     | 293/625 [00:35<00:40,  8.10it/s]
#
#
#
#  47%|████▋     | 294/625 [00:36<00:40,  8.10it/s]
#
#
#
#  47%|████▋     | 295/625 [00:36<00:40,  8.10it/s]
#
#
#
#  47%|████▋     | 296/625 [00:36<00:40,  8.10it/s]
#
#
#
#  48%|████▊     | 297/625 [00:36<00:40,  8.10it/s]
#
#
#
#  48%|████▊     | 298/625 [00:36<00:40,  8.10it/s]
#
#
#
#  48%|████▊     | 299/625 [00:36<00:40,  8.09it/s]
#
#
#
#  48%|████▊     | 300/625 [00:36<00:40,  8.10it/s]
#
#
#
#  48%|████▊     | 301/625 [00:36<00:39,  8.10it/s]
#
#
#
#  48%|████▊     | 302/625 [00:37<00:39,  8.11it/s]
#
#
#
#  48%|████▊     | 303/625 [00:37<00:39,  8.11it/s]
#
#
#
#  49%|████▊     | 304/625 [00:37<00:39,  8.11it/s]
#
#
#
#  49%|████▉     | 305/625 [00:37<00:39,  8.11it/s]
#
#
#
#  49%|████▉     | 306/625 [00:37<00:39,  8.11it/s]
#
#
#
#  49%|████▉     | 307/625 [00:37<00:39,  8.10it/s]
#
#
#
#  49%|████▉     | 308/625 [00:37<00:39,  8.10it/s]
#
#
#
#  49%|████▉     | 309/625 [00:37<00:38,  8.10it/s]
#
#
#
#  50%|████▉     | 310/625 [00:38<00:38,  8.11it/s]
#
#
#
#  50%|████▉     | 311/625 [00:38<00:38,  8.11it/s]
#
#
#
#  50%|████▉     | 312/625 [00:38<00:38,  8.11it/s]
#
#
#
#  50%|█████     | 313/625 [00:38<00:38,  8.11it/s]
#
#
#
#  50%|█████     | 314/625 [00:38<00:38,  8.10it/s]
#
#
#
#  50%|█████     | 315/625 [00:38<00:38,  8.10it/s]
#
#
#
#  51%|█████     | 316/625 [00:38<00:38,  8.10it/s]
#
#
#
#  51%|█████     | 317/625 [00:38<00:38,  8.10it/s]
#
#
#
#  51%|█████     | 318/625 [00:39<00:37,  8.10it/s]
#
#
#
#  51%|█████     | 319/625 [00:39<00:37,  8.10it/s]
#
#
#
#  51%|█████     | 320/625 [00:39<00:37,  8.11it/s]
#
#
#
#  51%|█████▏    | 321/625 [00:39<00:37,  8.11it/s]
#
#
#
#  52%|█████▏    | 322/625 [00:39<00:37,  8.10it/s]
#
#
#
#  52%|█████▏    | 323/625 [00:39<00:37,  8.10it/s]
#
#
#
#  52%|█████▏    | 324/625 [00:39<00:37,  8.09it/s]
#
#
#
#  52%|█████▏    | 325/625 [00:39<00:37,  8.09it/s]
#
#
#
#  52%|█████▏    | 326/625 [00:40<00:36,  8.10it/s]
#
#
#
#  52%|█████▏    | 327/625 [00:40<00:36,  8.10it/s]
#
#
#
#  52%|█████▏    | 328/625 [00:40<00:36,  8.10it/s]
#
#
#
#  53%|█████▎    | 329/625 [00:40<00:36,  8.11it/s]
#
#
#
#  53%|█████▎    | 330/625 [00:40<00:36,  8.11it/s]
#
#
#
#  53%|█████▎    | 331/625 [00:40<00:36,  8.10it/s]
#
#
#
#  53%|█████▎    | 332/625 [00:40<00:36,  8.09it/s]
#
#
#
#  53%|█████▎    | 333/625 [00:40<00:36,  8.09it/s]
#
#
#
#  53%|█████▎    | 334/625 [00:41<00:35,  8.09it/s]
#
#
#
#  54%|█████▎    | 335/625 [00:41<00:35,  8.08it/s]
#
#
#
#  54%|█████▍    | 336/625 [00:41<00:35,  8.09it/s]
#
#
#
#  54%|█████▍    | 337/625 [00:41<00:35,  8.09it/s]
#
#
#
#  54%|█████▍    | 338/625 [00:41<00:35,  8.09it/s]
#
#
#
#  54%|█████▍    | 339/625 [00:41<00:35,  8.09it/s]
#
#
#
#  54%|█████▍    | 340/625 [00:41<00:35,  8.09it/s]
#
#
#
#  55%|█████▍    | 341/625 [00:41<00:35,  8.09it/s]
#
#
#
#  55%|█████▍    | 342/625 [00:42<00:34,  8.10it/s]
#
#
#
#  55%|█████▍    | 343/625 [00:42<00:34,  8.09it/s]
#
#
#
#  55%|█████▌    | 344/625 [00:42<00:34,  8.10it/s]
#
#
#
#  55%|█████▌    | 345/625 [00:42<00:34,  8.10it/s]
#
#
#
#  55%|█████▌    | 346/625 [00:42<00:34,  8.10it/s]
#
#
#
#  56%|█████▌    | 347/625 [00:42<00:34,  8.09it/s]
#
#
#
#  56%|█████▌    | 348/625 [00:42<00:34,  8.09it/s]
#
#
#
#  56%|█████▌    | 349/625 [00:42<00:34,  8.10it/s]
#
#
#
#  56%|█████▌    | 350/625 [00:43<00:33,  8.10it/s]
#
#
#
#  56%|█████▌    | 351/625 [00:43<00:33,  8.09it/s]
#
#
#
#  56%|█████▋    | 352/625 [00:43<00:33,  8.09it/s]
#
#
#
#  56%|█████▋    | 353/625 [00:43<00:33,  8.09it/s]
#
#
#
#  57%|█████▋    | 354/625 [00:43<00:33,  8.09it/s]
#
#
#
#  57%|█████▋    | 355/625 [00:43<00:33,  8.08it/s]
#
#
#
#  57%|█████▋    | 356/625 [00:43<00:33,  8.08it/s]
#
#
#
#  57%|█████▋    | 357/625 [00:43<00:33,  8.09it/s]
#
#
#
#  57%|█████▋    | 358/625 [00:44<00:33,  8.09it/s]
#
#
#
#  57%|█████▋    | 359/625 [00:44<00:32,  8.08it/s]
#
#
#
#  58%|█████▊    | 360/625 [00:44<00:32,  8.08it/s]
#
#
#
#  58%|█████▊    | 361/625 [00:44<00:32,  8.08it/s]
#
#
#
#  58%|█████▊    | 362/625 [00:44<00:32,  8.09it/s]
#
#
#
#  58%|█████▊    | 363/625 [00:44<00:32,  8.09it/s]
#
#
#
#  58%|█████▊    | 364/625 [00:44<00:32,  8.09it/s]
#
#
#
#  58%|█████▊    | 365/625 [00:44<00:32,  8.09it/s]
#
#
#
#  59%|█████▊    | 366/625 [00:45<00:32,  8.09it/s]
#
#
#
#  59%|█████▊    | 367/625 [00:45<00:31,  8.09it/s]
#
#
#
#  59%|█████▉    | 368/625 [00:45<00:31,  8.09it/s]
#
#
#
#  59%|█████▉    | 369/625 [00:45<00:31,  8.09it/s]
#
#
#
#  59%|█████▉    | 370/625 [00:45<00:31,  8.09it/s]
#
#
#
#  59%|█████▉    | 371/625 [00:45<00:31,  8.09it/s]
#
#
#
#  60%|█████▉    | 372/625 [00:45<00:31,  8.08it/s]
#
#
#
#  60%|█████▉    | 373/625 [00:45<00:31,  8.09it/s]
#
#
#
#  60%|█████▉    | 374/625 [00:46<00:31,  8.09it/s]
#
#
#
#  60%|██████    | 375/625 [00:46<00:30,  8.08it/s]
#
#
#
#  60%|██████    | 376/625 [00:46<00:30,  8.08it/s]
#
#
#
#  60%|██████    | 377/625 [00:46<00:30,  8.08it/s]
#
#
#
#  60%|██████    | 378/625 [00:46<00:30,  8.08it/s]
#  61%|██████    | 379/625 [00:46<00:30,  8.09it/s]
#
#
#
#  61%|██████    | 380/625 [00:46<00:30,  8.08it/s]
#
#
#
#  61%|██████    | 381/625 [00:46<00:30,  8.08it/s]
#
#
#
#  61%|██████    | 382/625 [00:46<00:30,  8.08it/s]
#
#
#
#  61%|██████▏   | 383/625 [00:47<00:29,  8.08it/s]
#
#
#
#  61%|██████▏   | 384/625 [00:47<00:29,  8.08it/s]
#
#
#
#  62%|██████▏   | 385/625 [00:47<00:29,  8.08it/s]
#
#
#
#  62%|██████▏   | 386/625 [00:47<00:29,  8.08it/s]
#
#
#
#  62%|██████▏   | 387/625 [00:47<00:29,  8.08it/s]
#
#
#
#  62%|██████▏   | 388/625 [00:47<00:29,  8.07it/s]
#
#
#
#  62%|██████▏   | 389/625 [00:47<00:29,  8.08it/s]
#
#
#
#  62%|██████▏   | 390/625 [00:47<00:29,  8.08it/s]
#
#
#
#  63%|██████▎   | 391/625 [00:48<00:28,  8.08it/s]
#
#
#
#  63%|██████▎   | 392/625 [00:48<00:28,  8.08it/s]
#
#
#
#  63%|██████▎   | 393/625 [00:48<00:28,  8.08it/s]
#
#
#
#  63%|██████▎   | 394/625 [00:48<00:28,  8.09it/s]
#
#
#
#  63%|██████▎   | 395/625 [00:48<00:28,  8.08it/s]
#
#
#
#  63%|██████▎   | 396/625 [00:48<00:28,  8.08it/s]
#
#
#
#  64%|██████▎   | 397/625 [00:48<00:28,  8.08it/s]
#
#
#
#  64%|██████▎   | 398/625 [00:48<00:28,  8.08it/s]
#
#
#
#  64%|██████▍   | 399/625 [00:49<00:27,  8.09it/s]
#
#
#
#  64%|██████▍   | 400/625 [00:49<00:27,  8.08it/s]
#
#
#
#  64%|██████▍   | 401/625 [00:49<00:27,  8.08it/s]
#
#
#
#  64%|██████▍   | 402/625 [00:49<00:27,  8.07it/s]
#
#
#
#  64%|██████▍   | 403/625 [00:49<00:27,  8.08it/s]
#
#
#
#  65%|██████▍   | 404/625 [00:49<00:27,  8.08it/s]
#
#
#
#  65%|██████▍   | 405/625 [00:49<00:27,  8.08it/s]
#
#
#
#  65%|██████▍   | 406/625 [00:49<00:27,  8.08it/s]
#
#
#
#  65%|██████▌   | 407/625 [00:50<00:26,  8.08it/s]
#
#
#
#  65%|██████▌   | 408/625 [00:50<00:26,  8.08it/s]
#
#
#
#  65%|██████▌   | 409/625 [00:50<00:26,  8.08it/s]
#
#
#
#  66%|██████▌   | 410/625 [00:50<00:26,  8.08it/s]
#
#
#
#  66%|██████▌   | 411/625 [00:50<00:26,  8.08it/s]
#
#
#
#  66%|██████▌   | 412/625 [00:50<00:26,  8.07it/s]
#
#
#
#  66%|██████▌   | 413/625 [00:50<00:26,  8.08it/s]
#
#
#
#  66%|██████▌   | 414/625 [00:50<00:26,  8.08it/s]
#
#
#
#  66%|██████▋   | 415/625 [00:51<00:25,  8.08it/s]
#
#
#
#  67%|██████▋   | 416/625 [00:51<00:25,  8.08it/s]
#
#
#
#  67%|██████▋   | 417/625 [00:51<00:25,  8.08it/s]
#
#
#
#  67%|██████▋   | 418/625 [00:51<00:25,  8.08it/s]
#
#
#
#  67%|██████▋   | 419/625 [00:51<00:25,  8.08it/s]
#
#
#
#  67%|██████▋   | 420/625 [00:51<00:25,  8.08it/s]
#
#
#
#  67%|██████▋   | 421/625 [00:51<00:25,  8.08it/s]
#
#
#
#  68%|██████▊   | 422/625 [00:51<00:25,  8.07it/s]
#
#
#
#  68%|██████▊   | 423/625 [00:52<00:25,  8.08it/s]
#
#
#
#  68%|██████▊   | 424/625 [00:52<00:24,  8.08it/s]
#
#
#
#  68%|██████▊   | 425/625 [00:52<00:24,  8.08it/s]
#
#
#
#  68%|██████▊   | 426/625 [00:52<00:24,  8.08it/s]
#
#
#
#  68%|██████▊   | 427/625 [00:52<00:24,  8.08it/s]
#
#
#
#  68%|██████▊   | 428/625 [00:52<00:24,  8.08it/s]
#
#
#
#  69%|██████▊   | 429/625 [00:52<00:24,  8.08it/s]
#
#
#
#  69%|██████▉   | 430/625 [00:52<00:24,  8.07it/s]
#
#
#
#  69%|██████▉   | 431/625 [00:53<00:24,  8.07it/s]
#
#
#
#  69%|██████▉   | 432/625 [00:53<00:23,  8.07it/s]
#
#
#
#  69%|██████▉   | 433/625 [00:53<00:23,  8.08it/s]
#
#
#
#  69%|██████▉   | 434/625 [00:53<00:23,  8.07it/s]
#
#
#
#  70%|██████▉   | 435/625 [00:53<00:23,  8.08it/s]
#
#
#
#  70%|██████▉   | 436/625 [00:53<00:23,  8.07it/s]
#
#
#
#  70%|██████▉   | 437/625 [00:53<00:23,  8.07it/s]
#
#
#
#  70%|███████   | 438/625 [00:53<00:23,  8.07it/s]
#
#
#
#  70%|███████   | 439/625 [00:54<00:23,  8.07it/s]
#
#
#
#  70%|███████   | 440/625 [00:54<00:22,  8.07it/s]
#
#
#
#  71%|███████   | 441/625 [00:54<00:22,  8.08it/s]
#
#
#
#  71%|███████   | 442/625 [00:54<00:22,  8.08it/s]
#
#
#
#  71%|███████   | 443/625 [00:54<00:22,  8.08it/s]
#
#
#
#  71%|███████   | 444/625 [00:54<00:22,  8.08it/s]
#
#
#
#  71%|███████   | 445/625 [00:54<00:22,  8.07it/s]
#
#
#
#  71%|███████▏  | 446/625 [00:54<00:22,  8.07it/s]
#
#
#
#  72%|███████▏  | 447/625 [00:55<00:22,  8.07it/s]
#
#
#
#  72%|███████▏  | 448/625 [00:55<00:21,  8.07it/s]
#
#
#
#  72%|███████▏  | 449/625 [00:55<00:21,  8.07it/s]
#
#
#
#  72%|███████▏  | 450/625 [00:55<00:21,  8.07it/s]
#
#
#
#  72%|███████▏  | 451/625 [00:55<00:21,  8.08it/s]
#
#
#
#  72%|███████▏  | 452/625 [00:55<00:21,  8.07it/s]
#
#
#
#  72%|███████▏  | 453/625 [00:55<00:21,  8.08it/s]
#
#
#
#  73%|███████▎  | 454/625 [00:55<00:21,  8.07it/s]
#
#
#
#  73%|███████▎  | 455/625 [00:56<00:21,  8.07it/s]
#
#
#
#  73%|███████▎  | 456/625 [00:56<00:20,  8.07it/s]
#
#
#
#  73%|███████▎  | 457/625 [00:56<00:20,  8.07it/s]
#
#
#
#  73%|███████▎  | 458/625 [00:56<00:20,  8.07it/s]
#
#
#
#  73%|███████▎  | 459/625 [00:56<00:20,  8.07it/s]
#
#
#
#  74%|███████▎  | 460/625 [00:56<00:20,  8.07it/s]
#
#
#
#  74%|███████▍  | 461/625 [00:56<00:20,  8.07it/s]
#
#
#
#  74%|███████▍  | 462/625 [00:56<00:20,  8.06it/s]
#
#
#
#  74%|███████▍  | 463/625 [00:57<00:20,  8.06it/s]
#
#
#
#  74%|███████▍  | 464/625 [00:57<00:19,  8.07it/s]
#
#
#
#  74%|███████▍  | 465/625 [00:57<00:19,  8.07it/s]
#
#
#
#  75%|███████▍  | 466/625 [00:57<00:19,  8.07it/s]
#
#
#
#  75%|███████▍  | 467/625 [00:57<00:19,  8.07it/s]
#
#
#
#  75%|███████▍  | 468/625 [00:57<00:19,  8.07it/s]
#
#
#
#  75%|███████▌  | 469/625 [00:57<00:19,  8.07it/s]
#
#
#
#  75%|███████▌  | 470/625 [00:57<00:19,  8.07it/s]
#
#
#
#  75%|███████▌  | 471/625 [00:58<00:19,  8.07it/s]
#
#
#
#  76%|███████▌  | 472/625 [00:58<00:18,  8.07it/s]
#
#
#
#  76%|███████▌  | 473/625 [00:58<00:18,  8.07it/s]
#
#
#
#  76%|███████▌  | 474/625 [00:58<00:18,  8.08it/s]
#
#
#
#  76%|███████▌  | 475/625 [00:58<00:18,  8.07it/s]
#
#
#
#  76%|███████▌  | 476/625 [00:58<00:18,  8.07it/s]
#
#
#
#  76%|███████▋  | 477/625 [00:58<00:18,  8.07it/s]
#
#
#
#  76%|███████▋  | 478/625 [00:58<00:18,  8.07it/s]
#
#
#
#  77%|███████▋  | 479/625 [00:59<00:18,  8.07it/s]
#
#
#
#  77%|███████▋  | 480/625 [00:59<00:17,  8.06it/s]
#
#
#
#  77%|███████▋  | 481/625 [00:59<00:17,  8.06it/s]
#
#
#
#  77%|███████▋  | 482/625 [00:59<00:17,  8.07it/s]
#
#
#
#  77%|███████▋  | 483/625 [00:59<00:17,  8.07it/s]
#
#
#
#  77%|███████▋  | 484/625 [00:59<00:17,  8.07it/s]
#
#
#
#  78%|███████▊  | 485/625 [00:59<00:17,  8.07it/s]
#
#
#
#  78%|███████▊  | 486/625 [00:59<00:17,  8.07it/s]
#
#
#
#  78%|███████▊  | 487/625 [00:59<00:17,  8.07it/s]
#
#
#
#  78%|███████▊  | 488/625 [01:00<00:16,  8.07it/s]
#
#
#
#  78%|███████▊  | 489/625 [01:00<00:16,  8.07it/s]
#
#
#
#  78%|███████▊  | 490/625 [01:00<00:16,  8.07it/s]
#
#
#
#  79%|███████▊  | 491/625 [01:00<00:16,  8.07it/s]
#
#
#
#  79%|███████▊  | 492/625 [01:00<00:16,  8.07it/s]
#
#
#
#  79%|███████▉  | 493/625 [01:00<00:16,  8.07it/s]
#
#
#
#  79%|███████▉  | 494/625 [01:00<00:16,  8.07it/s]
#
#
#
#  79%|███████▉  | 495/625 [01:00<00:16,  8.07it/s]
#
#
#
#  79%|███████▉  | 496/625 [01:01<00:15,  8.07it/s]
#
#
#
#  80%|███████▉  | 497/625 [01:01<00:15,  8.08it/s]
#
#
#
#  80%|███████▉  | 498/625 [01:01<00:15,  8.08it/s]
#
#
#
#  80%|███████▉  | 499/625 [01:01<00:15,  8.07it/s]
#
#
#
#  80%|████████  | 500/625 [01:01<00:15,  8.06it/s]
#
#
#
#  80%|████████  | 501/625 [01:01<00:15,  8.06it/s]
#
#
#
#  80%|████████  | 502/625 [01:01<00:15,  8.07it/s]
#
#
#
#  80%|████████  | 503/625 [01:01<00:15,  8.07it/s]
#
#
#
#  81%|████████  | 504/625 [01:02<00:14,  8.07it/s]
#  81%|████████  | 505/625 [01:02<00:14,  8.06it/s]
#
#
#
#  81%|████████  | 506/625 [01:02<00:14,  8.06it/s]
#
#
#
#  81%|████████  | 507/625 [01:02<00:14,  8.07it/s]
#
#
#
#  81%|████████▏ | 508/625 [01:02<00:14,  8.06it/s]
#
#
#
#  81%|████████▏ | 509/625 [01:02<00:14,  8.06it/s]
#
#
#
#  82%|████████▏ | 510/625 [01:02<00:14,  8.06it/s]
#
#
#
#  82%|████████▏ | 511/625 [01:02<00:14,  8.06it/s]
#
#
#
#  82%|████████▏ | 512/625 [01:03<00:14,  8.06it/s]
#
#
#
#  82%|████████▏ | 513/625 [01:03<00:13,  8.07it/s]
#
#
#
#  82%|████████▏ | 514/625 [01:03<00:13,  8.07it/s]
#
#
#
#  82%|████████▏ | 515/625 [01:03<00:13,  8.07it/s]
#
#
#
#  83%|████████▎ | 516/625 [01:03<00:13,  8.07it/s]
#
#
#
#  83%|████████▎ | 517/625 [01:03<00:13,  8.06it/s]
#
#
#
#  83%|████████▎ | 518/625 [01:03<00:13,  8.06it/s]
#
#
#
#  83%|████████▎ | 519/625 [01:03<00:13,  8.06it/s]
#
#
#
#  83%|████████▎ | 520/625 [01:04<00:13,  8.07it/s]
#
#
#
#  83%|████████▎ | 521/625 [01:04<00:12,  8.06it/s]
#
#
#
#  84%|████████▎ | 522/625 [01:04<00:12,  8.06it/s]
#
#
#
#  84%|████████▎ | 523/625 [01:04<00:12,  8.06it/s]
#
#
#
#  84%|████████▍ | 524/625 [01:04<00:12,  8.07it/s]
#
#
#
#  84%|████████▍ | 525/625 [01:04<00:12,  8.07it/s]
#
#
#
#  84%|████████▍ | 526/625 [01:04<00:12,  8.06it/s]
#
#
#
#  84%|████████▍ | 527/625 [01:04<00:12,  8.06it/s]
#
#
#
#  84%|████████▍ | 528/625 [01:05<00:12,  8.07it/s]
#
#
#
#  85%|████████▍ | 529/625 [01:05<00:11,  8.07it/s]
#
#
#
#  85%|████████▍ | 530/625 [01:05<00:11,  8.06it/s]
#
#
#
#  85%|████████▍ | 531/625 [01:05<00:11,  8.06it/s]
#
#
#
#  85%|████████▌ | 532/625 [01:05<00:11,  8.06it/s]
#
#
#
#  85%|████████▌ | 533/625 [01:05<00:11,  8.06it/s]
#
#
#
#  85%|████████▌ | 534/625 [01:05<00:11,  8.06it/s]
#
#
#
#  86%|████████▌ | 535/625 [01:05<00:11,  8.07it/s]
#
#
#
#  86%|████████▌ | 536/625 [01:06<00:11,  8.06it/s]
#
#
#
#  86%|████████▌ | 537/625 [01:06<00:10,  8.06it/s]
#
#
#
#  86%|████████▌ | 538/625 [01:06<00:10,  8.06it/s]
#
#
#
#  86%|████████▌ | 539/625 [01:06<00:10,  8.07it/s]
#
#
#
#  86%|████████▋ | 540/625 [01:06<00:10,  8.06it/s]
#
#
#
#  87%|████████▋ | 541/625 [01:06<00:10,  8.05it/s]
#
#
#
#  87%|████████▋ | 542/625 [01:06<00:10,  8.06it/s]
#
#
#
#  87%|████████▋ | 543/625 [01:06<00:10,  8.06it/s]
#
#
#
#  87%|████████▋ | 544/625 [01:07<00:10,  8.06it/s]
#
#
#
#  87%|████████▋ | 545/625 [01:07<00:09,  8.06it/s]
#
#
#
#  87%|████████▋ | 546/625 [01:07<00:09,  8.06it/s]
#
#
#
#  88%|████████▊ | 547/625 [01:07<00:09,  8.06it/s]
#
#
#
#  88%|████████▊ | 548/625 [01:07<00:09,  8.06it/s]
#
#
#
#  88%|████████▊ | 549/625 [01:07<00:09,  8.05it/s]
#
#
#
#  88%|████████▊ | 550/625 [01:07<00:09,  8.04it/s]
#
#
#
#  88%|████████▊ | 551/625 [01:07<00:09,  8.04it/s]
#
#
#
#  88%|████████▊ | 552/625 [01:08<00:09,  8.05it/s]
#
#
#
#  88%|████████▊ | 553/625 [01:08<00:08,  8.05it/s]
#
#
#
#  89%|████████▊ | 554/625 [01:08<00:08,  8.05it/s]
#
#
#
#  89%|████████▉ | 555/625 [01:08<00:08,  8.06it/s]
#
#
#
#  89%|████████▉ | 556/625 [01:08<00:08,  8.06it/s]
#
#
#
#  89%|████████▉ | 557/625 [01:08<00:08,  8.06it/s]
#
#
#
#  89%|████████▉ | 558/625 [01:08<00:08,  8.06it/s]
#
#
#
#  89%|████████▉ | 559/625 [01:08<00:08,  8.07it/s]
#
#
#
#  90%|████████▉ | 560/625 [01:09<00:08,  8.07it/s]
#
#
#
#  90%|████████▉ | 561/625 [01:09<00:07,  8.07it/s]
#
#
#
#  90%|████████▉ | 562/625 [01:09<00:07,  8.07it/s]
#
#
#
#  90%|█████████ | 563/625 [01:09<00:07,  8.06it/s]
#
#
#
#  90%|█████████ | 564/625 [01:09<00:07,  8.07it/s]
#
#
#
#  90%|█████████ | 565/625 [01:09<00:07,  8.06it/s]
#
#
#
#  91%|█████████ | 566/625 [01:09<00:07,  8.06it/s]
#
#
#
#  91%|█████████ | 567/625 [01:09<00:07,  8.06it/s]
#
#
#
#  91%|█████████ | 568/625 [01:10<00:07,  8.06it/s]
#
#
#
#  91%|█████████ | 569/625 [01:10<00:06,  8.07it/s]
#
#
#
#  91%|█████████ | 570/625 [01:10<00:06,  8.07it/s]
#
#
#
#  91%|█████████▏| 571/625 [01:10<00:06,  8.06it/s]
#
#
#
#  92%|█████████▏| 572/625 [01:10<00:06,  8.07it/s]
#
#
#
#  92%|█████████▏| 573/625 [01:10<00:06,  8.06it/s]
#
#
#
#  92%|█████████▏| 574/625 [01:10<00:06,  8.06it/s]
#
#
#
#  92%|█████████▏| 575/625 [01:10<00:06,  8.06it/s]
#
#
#
#  92%|█████████▏| 576/625 [01:11<00:06,  8.06it/s]
#
#
#
#  92%|█████████▏| 577/625 [01:11<00:05,  8.06it/s]
#
#
#
#  92%|█████████▏| 578/625 [01:11<00:05,  8.06it/s]
#
#
#
#  93%|█████████▎| 579/625 [01:11<00:05,  8.06it/s]
#
#
#
#  93%|█████████▎| 580/625 [01:11<00:05,  8.07it/s]
#
#
#
#  93%|█████████▎| 581/625 [01:11<00:05,  8.06it/s]
#
#
#
#  93%|█████████▎| 582/625 [01:11<00:05,  8.06it/s]
#
#
#
#  93%|█████████▎| 583/625 [01:11<00:05,  8.05it/s]
#
#
#
#  93%|█████████▎| 584/625 [01:12<00:05,  8.06it/s]
#
#
#
#  94%|█████████▎| 585/625 [01:12<00:04,  8.06it/s]
#
#
#
#  94%|█████████▍| 586/625 [01:12<00:04,  8.06it/s]
#
#
#
#  94%|█████████▍| 587/625 [01:12<00:04,  8.06it/s]
#
#
#
#  94%|█████████▍| 588/625 [01:12<00:04,  8.06it/s]
#
#
#
#  94%|█████████▍| 589/625 [01:12<00:04,  8.06it/s]
#
#
#
#  94%|█████████▍| 590/625 [01:12<00:04,  8.06it/s]
#
#
#
#  95%|█████████▍| 591/625 [01:12<00:04,  8.06it/s]
#
#
#
#  95%|█████████▍| 592/625 [01:13<00:04,  8.05it/s]
#
#
#
#  95%|█████████▍| 593/625 [01:13<00:03,  8.06it/s]
#
#
#
#  95%|█████████▌| 594/625 [01:13<00:03,  8.07it/s]
#
#
#
#  95%|█████████▌| 595/625 [01:13<00:03,  8.07it/s]
#
#
#
#  95%|█████████▌| 596/625 [01:13<00:03,  8.07it/s]
#
#
#
#  96%|█████████▌| 597/625 [01:13<00:03,  8.07it/s]
#
#
#
#  96%|█████████▌| 598/625 [01:13<00:03,  8.06it/s]
#
#
#
#  96%|█████████▌| 599/625 [01:13<00:03,  8.05it/s]
#
#
#
#  96%|█████████▌| 600/625 [01:14<00:03,  8.06it/s]
#
#
#
#  96%|█████████▌| 601/625 [01:14<00:02,  8.06it/s]
#
#
#
#  96%|█████████▋| 602/625 [01:14<00:02,  8.06it/s]
#
#
#
#  96%|█████████▋| 603/625 [01:14<00:02,  8.06it/s]
#
#
#
#  97%|█████████▋| 604/625 [01:14<00:02,  8.06it/s]
#
#
#
#  97%|█████████▋| 605/625 [01:14<00:02,  8.06it/s]
#
#
#
#  97%|█████████▋| 606/625 [01:14<00:02,  8.06it/s]
#
#
#
#  97%|█████████▋| 607/625 [01:14<00:02,  8.06it/s]
#
#
#
#  97%|█████████▋| 608/625 [01:15<00:02,  8.06it/s]
#
#
#
#  97%|█████████▋| 609/625 [01:15<00:01,  8.06it/s]
#
#
#
#  98%|█████████▊| 610/625 [01:15<00:01,  8.06it/s]
#
#
#
#  98%|█████████▊| 611/625 [01:15<00:01,  8.06it/s]
#
#
#
#  98%|█████████▊| 612/625 [01:15<00:01,  8.06it/s]
#
#
#
#  98%|█████████▊| 613/625 [01:15<00:01,  8.07it/s]
#
#
#
#  98%|█████████▊| 614/625 [01:15<00:01,  8.06it/s]
#
#
#
#  98%|█████████▊| 615/625 [01:15<00:01,  8.06it/s]
#
#
#
#  99%|█████████▊| 616/625 [01:15<00:01,  8.06it/s]
#
#
#
#  99%|█████████▊| 617/625 [01:16<00:00,  8.07it/s]
#
#
#
#  99%|█████████▉| 618/625 [01:16<00:00,  8.06it/s]
#
#
#
#  99%|█████████▉| 619/625 [01:16<00:00,  8.06it/s]
#
#
#
#  99%|█████████▉| 620/625 [01:16<00:00,  8.06it/s]
#
#
#
#  99%|█████████▉| 621/625 [01:16<00:00,  8.07it/s]
#
#
#
# 100%|█████████▉| 622/625 [01:16<00:00,  8.06it/s]
#
#
#
# 100%|█████████▉| 623/625 [01:16<00:00,  8.06it/s]
#
#
#
# 100%|█████████▉| 624/625 [01:16<00:00,  8.06it/s]
#
#
#
# 100%|██████████| 625/625 [01:17<00:00,  8.11it/s]

# %%
X_data = np.vstack(bert_output)
y = data_pd["label"].values[0:10000]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X_data, y, test_size=0.3, random_state=42, stratify=y)

X_train,X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

print (X_train.shape,X_test.shape, X_val.shape)
# Out:
# (5600, 768) (3000, 768) (1400, 768)

# %%
from keras.layers import *
from keras.models import Model
from keras.callbacks import ModelCheckpoint


input_layer = Input(shape=(768,))
hidden_dense_layer = Dense(250,activation="sigmoid")(input_layer)
dense_layer = Dense(1,activation="sigmoid")(hidden_dense_layer)

model = Model(inputs=input_layer, outputs=dense_layer)
model.compile(loss='binary_crossentropy', optimizer="adam",metrics=["accuracy"])
print (model.summary())
mc = ModelCheckpoint("best_checkpoint.h5", monitor="val_acc" , save_best_only=True, save_weights_only=True)

model.fit(X_train,y_train,validation_data=(X_val,y_val), epochs= 50, batch_size=50, callbacks=[mc])
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 768)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               192250
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 251
# =================================================================
# Total params: 192,501
# Trainable params: 192,501
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 5600 samples, validate on 1400 samples
# Epoch 1/50
# 5600/5600 [==============================] - 0s 47us/step - loss: 0.4583 - accuracy: 0.7879 - val_loss: 0.4198 - val_accuracy: 0.8050
# Epoch 2/50
# 5600/5600 [==============================] - 0s 45us/step - loss: 0.3618 - accuracy: 0.8448 - val_loss: 0.4271 - val_accuracy: 0.8000
# Epoch 3/50
# 5600/5600 [==============================] - 1s 143us/step - loss: 0.3467 - accuracy: 0.8455 - val_loss: 0.4010 - val_accuracy: 0.8164
# Epoch 4/50
# 5600/5600 [==============================] - 1s 142us/step - loss: 0.3263 - accuracy: 0.8582 - val_loss: 0.4192 - val_accuracy: 0.8121
# Epoch 5/50
# 5600/5600 [==============================] - 1s 115us/step - loss: 0.3215 - accuracy: 0.8636 - val_loss: 0.3951 - val_accuracy: 0.8264
# Epoch 6/50
# 5600/5600 [==============================] - 1s 122us/step - loss: 0.3140 - accuracy: 0.8666 - val_loss: 0.3964 - val_accuracy: 0.8121
# Epoch 7/50
# 5600/5600 [==============================] - 1s 127us/step - loss: 0.3097 - accuracy: 0.8702 - val_loss: 0.4089 - val_accuracy: 0.8100
# Epoch 8/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.3108 - accuracy: 0.8657 - val_loss: 0.4029 - val_accuracy: 0.8279
# Epoch 9/50
# 5600/5600 [==============================] - 1s 123us/step - loss: 0.2995 - accuracy: 0.8698 - val_loss: 0.4097 - val_accuracy: 0.8164
# Epoch 10/50
# 5600/5600 [==============================] - 1s 130us/step - loss: 0.2989 - accuracy: 0.8736 - val_loss: 0.3997 - val_accuracy: 0.8314
# Epoch 11/50
# 5600/5600 [==============================] - 1s 139us/step - loss: 0.2935 - accuracy: 0.8764 - val_loss: 0.4064 - val_accuracy: 0.8207
# Epoch 12/50
# 5600/5600 [==============================] - 1s 145us/step - loss: 0.2944 - accuracy: 0.8729 - val_loss: 0.4105 - val_accuracy: 0.8150
# Epoch 13/50
# 5600/5600 [==============================] - 1s 123us/step - loss: 0.2874 - accuracy: 0.8782 - val_loss: 0.3980 - val_accuracy: 0.8243
# Epoch 14/50
# 5600/5600 [==============================] - 1s 95us/step - loss: 0.2854 - accuracy: 0.8782 - val_loss: 0.4121 - val_accuracy: 0.8300
# Epoch 15/50
# 5600/5600 [==============================] - 1s 145us/step - loss: 0.2815 - accuracy: 0.8830 - val_loss: 0.3997 - val_accuracy: 0.8243
# Epoch 16/50
# 5600/5600 [==============================] - 1s 108us/step - loss: 0.2933 - accuracy: 0.8727 - val_loss: 0.4016 - val_accuracy: 0.8321
# Epoch 17/50
# 5600/5600 [==============================] - 1s 134us/step - loss: 0.2795 - accuracy: 0.8782 - val_loss: 0.4053 - val_accuracy: 0.8307
# Epoch 18/50
# 5600/5600 [==============================] - 1s 102us/step - loss: 0.2709 - accuracy: 0.8857 - val_loss: 0.4137 - val_accuracy: 0.8157
# Epoch 19/50
# 5600/5600 [==============================] - 1s 128us/step - loss: 0.2764 - accuracy: 0.8809 - val_loss: 0.4041 - val_accuracy: 0.8271
# Epoch 20/50
# 5600/5600 [==============================] - 1s 146us/step - loss: 0.2658 - accuracy: 0.8891 - val_loss: 0.4215 - val_accuracy: 0.8121
# Epoch 21/50
# 5600/5600 [==============================] - 1s 124us/step - loss: 0.2676 - accuracy: 0.8863 - val_loss: 0.4170 - val_accuracy: 0.8286
# Epoch 22/50
# 5600/5600 [==============================] - 1s 112us/step - loss: 0.2653 - accuracy: 0.8863 - val_loss: 0.4087 - val_accuracy: 0.8271
# Epoch 23/50
# 5600/5600 [==============================] - 1s 103us/step - loss: 0.2613 - accuracy: 0.8909 - val_loss: 0.4118 - val_accuracy: 0.8214
# Epoch 24/50
# 5600/5600 [==============================] - 1s 102us/step - loss: 0.2578 - accuracy: 0.8927 - val_loss: 0.4163 - val_accuracy: 0.8279
# Epoch 25/50
# 5600/5600 [==============================] - 1s 143us/step - loss: 0.2524 - accuracy: 0.8959 - val_loss: 0.4121 - val_accuracy: 0.8214
# Epoch 26/50
# 5600/5600 [==============================] - 1s 112us/step - loss: 0.2545 - accuracy: 0.8939 - val_loss: 0.4028 - val_accuracy: 0.8286
# Epoch 27/50
# 5600/5600 [==============================] - 1s 109us/step - loss: 0.2477 - accuracy: 0.8957 - val_loss: 0.4029 - val_accuracy: 0.8264
# Epoch 28/50
# 5600/5600 [==============================] - 1s 143us/step - loss: 0.2419 - accuracy: 0.8998 - val_loss: 0.4169 - val_accuracy: 0.8264
# Epoch 29/50
# 5600/5600 [==============================] - 1s 108us/step - loss: 0.2443 - accuracy: 0.8998 - val_loss: 0.4081 - val_accuracy: 0.8271
# Epoch 30/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.2356 - accuracy: 0.9023 - val_loss: 0.4126 - val_accuracy: 0.8236
# Epoch 31/50
# 5600/5600 [==============================] - 1s 121us/step - loss: 0.2378 - accuracy: 0.9030 - val_loss: 0.4117 - val_accuracy: 0.8229
# Epoch 32/50
# 5600/5600 [==============================] - 1s 138us/step - loss: 0.2317 - accuracy: 0.9039 - val_loss: 0.4817 - val_accuracy: 0.8071
# Epoch 33/50
# 5600/5600 [==============================] - 1s 145us/step - loss: 0.2281 - accuracy: 0.9062 - val_loss: 0.4111 - val_accuracy: 0.8229
# Epoch 34/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.2241 - accuracy: 0.9121 - val_loss: 0.4303 - val_accuracy: 0.8221
# Epoch 35/50
# 5600/5600 [==============================] - 1s 118us/step - loss: 0.2169 - accuracy: 0.9127 - val_loss: 0.4394 - val_accuracy: 0.8186
# Epoch 36/50
# 5600/5600 [==============================] - 1s 114us/step - loss: 0.2124 - accuracy: 0.9136 - val_loss: 0.4438 - val_accuracy: 0.8121
# Epoch 37/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.2090 - accuracy: 0.9166 - val_loss: 0.4302 - val_accuracy: 0.8250
# Epoch 38/50
# 5600/5600 [==============================] - 1s 143us/step - loss: 0.2058 - accuracy: 0.9141 - val_loss: 0.4262 - val_accuracy: 0.8250
# Epoch 39/50
# 5600/5600 [==============================] - 1s 106us/step - loss: 0.1938 - accuracy: 0.9234 - val_loss: 0.4395 - val_accuracy: 0.8214
# Epoch 40/50
# 5600/5600 [==============================] - 1s 104us/step - loss: 0.1920 - accuracy: 0.9225 - val_loss: 0.4406 - val_accuracy: 0.8179
# Epoch 41/50
# 5600/5600 [==============================] - 0s 62us/step - loss: 0.1835 - accuracy: 0.9286 - val_loss: 0.4309 - val_accuracy: 0.8229
# Epoch 42/50
# 5600/5600 [==============================] - 1s 142us/step - loss: 0.1841 - accuracy: 0.9296 - val_loss: 0.4496 - val_accuracy: 0.8171
# Epoch 43/50
# 5600/5600 [==============================] - 1s 145us/step - loss: 0.1757 - accuracy: 0.9330 - val_loss: 0.4713 - val_accuracy: 0.8164
# Epoch 44/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.1708 - accuracy: 0.9370 - val_loss: 0.4387 - val_accuracy: 0.8186
# Epoch 45/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.1641 - accuracy: 0.9377 - val_loss: 0.4532 - val_accuracy: 0.8214
# Epoch 46/50
# 5600/5600 [==============================] - 1s 145us/step - loss: 0.1602 - accuracy: 0.9405 - val_loss: 0.4598 - val_accuracy: 0.8243
# Epoch 47/50
# 5600/5600 [==============================] - 1s 126us/step - loss: 0.1603 - accuracy: 0.9384 - val_loss: 0.4501 - val_accuracy: 0.8236
# Epoch 48/50
# 5600/5600 [==============================] - 1s 134us/step - loss: 0.1476 - accuracy: 0.9471 - val_loss: 0.4763 - val_accuracy: 0.8200
# Epoch 49/50
# 5600/5600 [==============================] - 1s 145us/step - loss: 0.1413 - accuracy: 0.9495 - val_loss: 0.4714 - val_accuracy: 0.8243
# Epoch 50/50
# 5600/5600 [==============================] - 1s 144us/step - loss: 0.1369 - accuracy: 0.9530 - val_loss: 0.4643 - val_accuracy: 0.8179

# %%
model.evaluate(X_test,y_test)
# Out:
# 3000/3000 [==============================] - 0s 19us/step
# [0.3936431167125702, 0.8453333377838135]
